# %% [markdown]
# **for python objects**

# %%
print("no way")
# Out:
# no way

# %%
Num1 = 23
Num2 = 23

if Num1 > Num2:
  print("Num1 is bigger")
else:
  print("it is not bigger")
# Out:
# it is not bigger

# %% [markdown]
# ### **for problem solving study case**

# %%
sales = [122, 78, 100]
months = ['Jan', 'Feb', 'Mar']

# %%
total_sales = sum(sales)
print("total sales is ", total_sales)
# Out:
# total sales is  300

# %%
total_sales
# Out:
# 300

# %%
total_sales = sum(sales)
num_sales = len(sales)
average_sales = total_sales / num_sales
print(average_sales)
# Out:
# 100.0

# %%
# plot the results
from matplotlib import pyplot as plt
plt.plot(months, sales)

# %%
from matplotlib import pyplot as plt
plt.plot(sales, months)

# %% [markdown]
# ## **for simple interest calculator**

# %%
amount_borrowd = input("amount borrowed ")
interest_rate = input("interest rate ")
loan_period = input("loan period ")
simple_interest = int(amount_borrowed) * int(interest_rate) * int(loan_period) /100
print ("the simple interest is: ", simple_interest)
# Out:
# amount borrowed 100000
# interest rate 15
# loan period 20
# the simple interest is:  300000.0
